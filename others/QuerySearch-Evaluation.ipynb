# %%
import faiss
import os
import pandas as pd
import numpy 
import glob
import numpy as np
from skimage import measure, transform, feature
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
import ml_metrics as metrics
# %matplotlib inline

# %%
# DB details
NPZ_FEAT_SRC = "/local/cs572/rchan31/codespace/BaselinePrototype/npz_file_saves/COMPACT_NPZ_DELF_FEATS/"
FAISS_INDEX_FILE = "/local/cs572/rchan31/fINALwEEK/FAISSIndex/FAISS_delf_v1.index"
IMG_SRC_PATH = "/local/cs572/cziems/index/"

DB_LOOKUP_CSV = "/local/cs572/rchan31/fINALwEEK/csv_lookups/FAISS_delf_v1_CSV_lookup.csv"
N_INDEX = 952133

# %%
cpu_index = faiss.read_index(FAISS_INDEX_FILE)

cpu_index.ntotal
# Out:
# 952133

# %%
# Query details
Q_NPZ_FEAT_SRC = "/local/cs572/rchan31/fINALwEEK/COMPACT_NPZ_DELF_test_FEATS"
Q_IMG_SRC_PATH = "/local/cs572/cziems/test/"

Q_LOOKUP_CSV = "/local/cs572/rchan31/fINALwEEK/csv_lookups/processed_retrieval_solutions.csv"
Q_N_INDEX = 667

RERANKED_LIST_CSV = "/local/cs572/rchan31/fINALwEEK/csv_lookups/reranked_retrievals_delf_v1.csv"

# %%
# query-collection
query_df = pd.read_csv(Q_LOOKUP_CSV)
query_image_IDs = query_df["id"]
len(query_image_IDs)
# Out:
# 667

# %%
quer_vecs = []
quer_ids = {}
for i, fn in enumerate(glob.glob(os.path.join(Q_NPZ_FEAT_SRC, "*.npz"))):
    ID = os.path.basename(fn)[:-4]
    vec = np.load(fn)["descriptors"]
    quer_vecs.append(np.asarray(vec[0, :], dtype=np.float32))
    quer_ids[i] = ID
quer_vecs = np.array(quer_vecs)

quer_vecs.shape
# Out:
# (667, 40)

# %%
TOP_K = 100

cpu_index.nprobe = 100

distances, indices = cpu_index.search(quer_vecs, TOP_K)
print(distances.shape)
print(indices.shape)

indices
# Out:
# (667, 100)
# (667, 100)
# array([[736715, 363666, 948517, ..., 719896,  43536, 851043],
#        [501075, 543586, 575723, ..., 623293, 119295, 444459],
#        [229099, 775990, 410356, ..., 779317, 594871, 644500],
#        ...,
#        [255989, 528209, 108180, ..., 543274, 807051, 611768],
#        [568700, 641612, 916228, ..., 115030, 130539, 948178],
#        [406825, 673593, 472827, ..., 773443, 390467, 884963]])

# %%
db_df = pd.read_csv(DB_LOOKUP_CSV)
db_df.head()
# Out:
#    Unnamed: 0         filenames
# 0           0  00002469b818f290
# 1           1  0000298d976221f3
# 2           2  00002e4e382333bf
# 3           3  000036329c35b65c
# 4           4  0000394edaaa55b1

# %%
def match_retrievals(q_idx, query_id): # per query
    
    query_npz_path = os.path.join(Q_NPZ_FEAT_SRC, "%s.npz" % query_id)
    
    q_locations_x = np.asarray(np.load(query_npz_path)["locations_x"], np.int32)
    q_locations_y = np.asarray(np.load(query_npz_path)["locations_y"], np.int32)
    q_locations = np.asarray([q_locations_x, q_locations_y]).T
    
    num_features_q = q_locations.shape[0]

    query_db_inliers = {}
    db_ret_img_IDs = []
    for topk_idx, index_num in enumerate(indices[q_idx]):
        
        if index_num == -1:
            continue
        

        fileID = db_df.loc[index_num]["filenames"]
        
        db_npz_filename_path = os.path.join(NPZ_FEAT_SRC, "%s.npz" % fileID)
        insta_imageID = "%s.jpg" % fileID
        npz_data = np.load(db_npz_filename_path)
        
        inst_location_x = np.asarray(npz_data["locations_x"], np.int32)
        inst_location_y = np.asarray(npz_data["locations_y"], np.int32)
        db_locations = np.asarray([inst_location_x, inst_location_y]).T

        num_features_db = db_locations.shape[0]
        
        min_feat_len = min(num_features_q, num_features_db)


        # Perform geometric verification using RANSAC.
        _, inliers = measure.ransac((db_locations[:min_feat_len, :],
                                     q_locations[:min_feat_len, :]),
                                      transform.AffineTransform,
                                      min_samples=3,
                                      residual_threshold=20,
                                      max_trials=1000)

        print('Found %d inliers for image : %s.jpg' % (sum(inliers), fileID))
        query_db_inliers[fileID] = sum(inliers)
        db_ret_img_IDs.append(fileID)
        
#         if topk_idx == 2:
#             break


    db_ret_img_IDs.sort(key=query_db_inliers.get, reverse = True)
#     print(db_ret_img_IDs)
    
    if len(db_ret_img_IDs) != TOP_K:
        db_ret_img_IDs = db_ret_img_IDs + ['None'] * (TOP_K-len(db_ret_img_IDs))

    return db_ret_img_IDs


reranked_IDs = []
for q_idx, query_row in query_df.iterrows():
    sorted_db_ret_img_IDs = match_retrievals(q_idx, query_row["id"])
    reranked_IDs.append(sorted_db_ret_img_IDs)
    
    print("............ Finished reranking for query : %s.jpg : %d / %d" % (query_row["id"], q_idx, query_df.shape[0]))
    
    if q_idx == 2:
        break
        
# print(reranked_IDs)
reranked_df = pd.DataFrame(reranked_IDs)
reranked_df.insert(0, "queryImageID", query_df["id"])
# Out:
# Found 9 inliers for image : c62a9ca23e45420f.jpg
# Found 10 inliers for image : 61f08305fbc9f806.jpg
# Found 7 inliers for image : ff039f52ca878504.jpg
# Found 9 inliers for image : f258c7eb40fdc8cf.jpg
# Found 10 inliers for image : 7c9c6f52fd38e29b.jpg
# Found 8 inliers for image : 5cbb626ced45ba96.jpg
# Found 9 inliers for image : 9ae068672e7d8270.jpg
# Found 9 inliers for image : 61e5ac7b27f26e15.jpg
# Found 9 inliers for image : c800b2f0e4d23943.jpg
# Found 9 inliers for image : d54d45d1931a54c5.jpg
# Found 9 inliers for image : 0b222e3a8abd07ca.jpg
# Found 8 inliers for image : c604ef43fea8fbd1.jpg
# Found 7 inliers for image : 1ab719ee0f390fde.jpg
# Found 9 inliers for image : fbd33968c8cc0ffb.jpg
# Found 11 inliers for image : 06591603c89ba406.jpg
# Found 7 inliers for image : eb31b11020497621.jpg
# Found 7 inliers for image : 0177598b0a7f795b.jpg
# Found 9 inliers for image : b6218c7ee9d204f5.jpg
# Found 10 inliers for image : b26c637f44cfc1f1.jpg
# Found 9 inliers for image : d2c236ef72656b67.jpg
# Found 8 inliers for image : 8c30c019792d0e4e.jpg
# Found 10 inliers for image : 7606e8215e67dfaa.jpg
# Found 9 inliers for image : 66751118f8dfb075.jpg
# Found 10 inliers for image : 260cbab8cb6c396a.jpg
# Found 6 inliers for image : 00f76a32545a61fa.jpg
# Found 12 inliers for image : 795382a3476eef45.jpg
# Found 9 inliers for image : dddf2d75605c6802.jpg
# Found 6 inliers for image : 3171bbb1efba8ded.jpg
# Found 6 inliers for image : 5a17c286f55000f8.jpg
# Found 9 inliers for image : 9386f952a8da0b9b.jpg
# Found 9 inliers for image : 9ede993452a70324.jpg
# Found 12 inliers for image : f7516eb6373880a8.jpg
# Found 10 inliers for image : b4c1946352235ab8.jpg
# Found 12 inliers for image : 5b317bd61482003e.jpg
# Found 9 inliers for image : 097b25087f82804a.jpg
# Found 9 inliers for image : 1892697b72116342.jpg
# Found 8 inliers for image : c01f3d3c87983d97.jpg
# Found 11 inliers for image : cb160c4a3ebcf864.jpg
# Found 9 inliers for image : e8e39e2f44860de6.jpg
# Found 10 inliers for image : 1dff4ef33506ae51.jpg
# Found 12 inliers for image : 5b66021e346ab3c8.jpg
# Found 11 inliers for image : eb44afc3cfe9da05.jpg
# Found 10 inliers for image : 6a0607c5f8082ff1.jpg
# Found 6 inliers for image : 9543cd918ee87e38.jpg
# Found 11 inliers for image : 416c5f4354ea065a.jpg
# Found 9 inliers for image : 28fbb5aa65d85fda.jpg
# Found 9 inliers for image : b85475cfa8c4be26.jpg
# Found 11 inliers for image : 1be6bb8f89e9371f.jpg
# Found 11 inliers for image : e133f653b8621203.jpg
# Found 7 inliers for image : 2d7c947e119c171e.jpg
# Found 7 inliers for image : 44ad7312a2e2736d.jpg
# Found 10 inliers for image : 116b29bf355bd511.jpg
# Found 10 inliers for image : 49490d967cc0b035.jpg
# Found 7 inliers for image : 3656bc8f51848121.jpg
# Found 9 inliers for image : 1911e1570229167c.jpg
# Found 10 inliers for image : 377dbb48b6b7a1f1.jpg
# Found 7 inliers for image : 4f74155775b25cff.jpg
# Found 11 inliers for image : 799c81fc41f52331.jpg
# Found 12 inliers for image : 0ac20102062fcfe4.jpg
# Found 8 inliers for image : e9c5bb95cae12a4f.jpg
# Found 9 inliers for image : 7a1a8937bffd1875.jpg
# Found 10 inliers for image : c42dfd570cb4540d.jpg
# Found 10 inliers for image : a4e540fa8a35c35a.jpg
# Found 8 inliers for image : 71dd167d99dfdc26.jpg
# Found 11 inliers for image : f183d66ee8d9e069.jpg
# Found 9 inliers for image : fd324a696da3376f.jpg
# Found 13 inliers for image : 6743b01ed9a80b21.jpg
# Found 8 inliers for image : 9bc7c23fd20a9f4f.jpg
# Found 7 inliers for image : 57bed4879d4665a8.jpg
# Found 10 inliers for image : 646de1c261643229.jpg
# Found 6 inliers for image : b22b1d598e405a32.jpg
# Found 8 inliers for image : b7c5f7704a5d6898.jpg
# Found 9 inliers for image : ff6c81b6784eeaf8.jpg
# Found 8 inliers for image : 490cd63c0ffbcb4e.jpg
# Found 9 inliers for image : 6442b391ef46edf0.jpg
# Found 10 inliers for image : 65017405621c9bb4.jpg
# Found 8 inliers for image : 3db8c4cfa2b13939.jpg
# Found 11 inliers for image : 6006c6caee0d4f18.jpg
# Found 9 inliers for image : 8994d5e91350e4f4.jpg
# Found 7 inliers for image : 36b3b6c5572b91ad.jpg
# Found 7 inliers for image : f87b9cbd29f65b13.jpg
# Found 9 inliers for image : 6ada28fe7d930df5.jpg
# Found 10 inliers for image : 3352d6ad817a514a.jpg
# Found 10 inliers for image : 353cdc982697ebb9.jpg
# Found 10 inliers for image : 46c3ed8ef09b5119.jpg
# Found 10 inliers for image : ddb5178a5397776d.jpg
# Found 10 inliers for image : ba9627ba978958e9.jpg
# Found 7 inliers for image : fc7af51823e9137a.jpg
# Found 7 inliers for image : d9467598a6f2c341.jpg
# Found 6 inliers for image : 4025b17b3449da20.jpg
# Found 11 inliers for image : 8e0eaa513a8af4db.jpg
# Found 9 inliers for image : d27ece3ea4f076eb.jpg
# Found 8 inliers for image : ceac48e131c8b88d.jpg
# Found 12 inliers for image : 2389c6f3ae0d098c.jpg
# Found 8 inliers for image : f82730e8dac3257e.jpg
# Found 8 inliers for image : dc7854a19ce80576.jpg
# Found 10 inliers for image : b9c367d64335ecd3.jpg
# Found 5 inliers for image : c1a50fc8a5713159.jpg
# Found 10 inliers for image : 0bb3b80c15238c02.jpg
# Found 9 inliers for image : e4d4026892f0f21a.jpg
# Found 15 inliers for image : 86b37c8c6c559b21.jpg
# Found 18 inliers for image : 921f02216a181a18.jpg
# Found 19 inliers for image : 9adc544d34892d6a.jpg
# Found 16 inliers for image : 720382171af17c2f.jpg
# Found 17 inliers for image : 8b21751541e80559.jpg
# Found 16 inliers for image : e25485a00530097d.jpg
# Found 8 inliers for image : 5f443f06cae15cd5.jpg
# Found 16 inliers for image : 3f84e9a136feffa2.jpg
# Found 14 inliers for image : d2726ef324ceb7e8.jpg
# Found 17 inliers for image : 1e499b80114c29d2.jpg
# Found 15 inliers for image : a3f59774d72441bc.jpg
# Found 13 inliers for image : 0667b63b92371614.jpg
# Found 15 inliers for image : 85b648051c8e2ed8.jpg
# Found 17 inliers for image : b411ddd27256ffe1.jpg
# Found 16 inliers for image : db1cc9bd5965401d.jpg
# Found 12 inliers for image : 11186f6508973ce5.jpg
# Found 17 inliers for image : baab06c786b24be0.jpg
# Found 15 inliers for image : ff8df4e4557724cd.jpg
# Found 17 inliers for image : 9010a6725ebc6b68.jpg
# Found 14 inliers for image : 13c6cdc816ae3c35.jpg
# Found 15 inliers for image : 437d4bf160c23ba8.jpg
# Found 16 inliers for image : 1689c0c3a6a55210.jpg
# Found 13 inliers for image : ad8042893a8e0845.jpg
# Found 19 inliers for image : a153c9c6daa1c533.jpg
# Found 13 inliers for image : dba149b665eee5c4.jpg
# Found 8 inliers for image : 07b7f7489addcf6e.jpg
# Found 11 inliers for image : ff8d7a1abf8b0c53.jpg
# Found 15 inliers for image : 675cc44ba0a5ae35.jpg
# Found 18 inliers for image : 9458354974361f83.jpg
# Found 16 inliers for image : 704fcf7e16e55a76.jpg
# Found 14 inliers for image : e30aba760e994d30.jpg
# Found 15 inliers for image : 9b42ad9c3af7f6ea.jpg
# Found 14 inliers for image : 16999c92749302da.jpg
# Found 14 inliers for image : 1b43f0ccfc92815e.jpg
# Found 16 inliers for image : d0d30b28d9e4f04f.jpg
# Found 15 inliers for image : 7019080ce34ea8ed.jpg
# Found 14 inliers for image : c2c8afcf7cb89547.jpg
# Found 14 inliers for image : 9ab2bc2dc13c8911.jpg
# Found 18 inliers for image : 094dd3087b8eb2b6.jpg
# Found 18 inliers for image : 3dfe0a1b754c2b79.jpg
# Found 15 inliers for image : b3b34fc5c59822d3.jpg
# Found 14 inliers for image : 7750286470628f1c.jpg
# Found 14 inliers for image : 914a1ab397eaa980.jpg
# Found 16 inliers for image : 26c1af2c82ee8b55.jpg
# Found 15 inliers for image : d244632f32e2c8b0.jpg
# Found 14 inliers for image : 7d7ecc2c53790b55.jpg
# Found 15 inliers for image : eecfd626bfbdb64d.jpg
# Found 19 inliers for image : 9a720ea3a239c7e2.jpg
# Found 17 inliers for image : f021b368d1aaf556.jpg
# Found 14 inliers for image : cfaf013af8154a81.jpg
# Found 16 inliers for image : 247e68daa8ba21dd.jpg
# Found 11 inliers for image : e19b111562e7ea47.jpg
# Found 15 inliers for image : 8927481fbde1e31b.jpg
# Found 13 inliers for image : a63ad125d3286bb8.jpg
# Found 14 inliers for image : c1f0385d8ddf9265.jpg
# Found 14 inliers for image : e153aecb1407da4e.jpg
# Found 17 inliers for image : 1612f86aabcb0f9b.jpg
# Found 14 inliers for image : 72bec49c454b5087.jpg
# Found 13 inliers for image : f9cd5b65f937d262.jpg
# Found 15 inliers for image : 07e17dee15121691.jpg
# Found 14 inliers for image : 47961b78142259b8.jpg
# Found 12 inliers for image : bc1256effd2d1a3e.jpg
# Found 17 inliers for image : 01b57d3c34233740.jpg
# Found 15 inliers for image : 38bfc46124d91337.jpg
# Found 12 inliers for image : f4cc1116e22ccd10.jpg
# Found 14 inliers for image : e8477c1f4f4aca88.jpg
# Found 15 inliers for image : 304fbfcb7d0ef6a6.jpg
# Found 18 inliers for image : bf62dece3bcddfef.jpg
# Found 15 inliers for image : 08db25a17bcae493.jpg
# Found 16 inliers for image : e51a1e477d8920e5.jpg
# Found 17 inliers for image : b938e5a4a39fe3a2.jpg
# Found 15 inliers for image : 0baa29f89c74c00a.jpg
# Found 15 inliers for image : 567bb779fd69a8e2.jpg
# Found 17 inliers for image : 80415b58b2f5c152.jpg
# Found 16 inliers for image : 09732d1eccb9fb56.jpg
# Found 11 inliers for image : 1adfc00c2c6689e6.jpg
# Found 16 inliers for image : 540b7ef985057321.jpg
# Found 11 inliers for image : f904c847e26279b1.jpg
# Found 14 inliers for image : b7712655c8e02711.jpg
# Found 16 inliers for image : cc79f83a0097cd80.jpg
# Found 16 inliers for image : 59d32872b083724f.jpg
# Found 15 inliers for image : a5214d96d0d7270d.jpg
# Found 15 inliers for image : 5562961f2e0e9ef8.jpg
# Found 16 inliers for image : ff234d589f357dbc.jpg
# Found 15 inliers for image : d8c02f9298c93d0b.jpg
# Found 17 inliers for image : 7baa5d5e57faa81a.jpg
# Found 15 inliers for image : 6f030f25cab3b68d.jpg
# Found 17 inliers for image : 3421cd84cfe8f558.jpg
# Found 15 inliers for image : 8b94757658c5f4cb.jpg
# Found 17 inliers for image : fed2969b5278a844.jpg
# Found 15 inliers for image : caddb647d2cbaf39.jpg
# Found 17 inliers for image : 47367775e52cd791.jpg
# Found 15 inliers for image : 735ed8d385f4d91e.jpg
# Found 12 inliers for image : 25ec89b5e07e16b8.jpg
# Found 17 inliers for image : 9d8dfe0b2e7d772d.jpg
# Found 17 inliers for image : 348c5d5e6ba34483.jpg
# Found 9 inliers for image : 58462343843646b0.jpg
# Found 15 inliers for image : a7b375b6a66d338c.jpg
# Found 18 inliers for image : 201e24b5cea6c46d.jpg
# Found 15 inliers for image : 777ef9d9e67e75b8.jpg
# Found 13 inliers for image : 3dcfb68630dae905.jpg
# Found 16 inliers for image : d0abe024e8e92459.jpg
# Found 16 inliers for image : 6e709c5b726a7527.jpg
# Found 13 inliers for image : 4327234a4d27d181.jpg
# Found 17 inliers for image : eebf7fc00415e13e.jpg
# Found 15 inliers for image : fc596e3a813e548b.jpg
# Found 14 inliers for image : 899fc319f90c23e3.jpg
# Found 15 inliers for image : 190b40938e2bd088.jpg
# Found 13 inliers for image : a6ee7fbd054d8e16.jpg
# Found 15 inliers for image : f25719080417dc30.jpg
# Found 15 inliers for image : ea09864509e36cbb.jpg
# Found 12 inliers for image : 5f566a8aa9b24fbd.jpg
# Found 13 inliers for image : 41cc012319859305.jpg
# Found 13 inliers for image : 21a90b2e4ce938f0.jpg
# Found 14 inliers for image : a2eb55797373deb8.jpg
# Found 14 inliers for image : 43bc9518fc20d36b.jpg
# Found 16 inliers for image : d34fcc91855cde45.jpg
# Found 14 inliers for image : f5f4e4bdb336cac4.jpg
# Found 15 inliers for image : 9cdc8562e028013c.jpg
# Found 16 inliers for image : bdef6c5d03b08571.jpg
# Found 14 inliers for image : 7ca2368edf8e9c64.jpg
# Found 16 inliers for image : 745b1eebf6f26189.jpg
# Found 13 inliers for image : 0de28218b7d4ec18.jpg
# Found 17 inliers for image : 7989bf0178906d80.jpg
# Found 14 inliers for image : 2c63a2952e097c60.jpg
# Found 13 inliers for image : fcd84fff7dd55867.jpg
# Found 14 inliers for image : 8e53fd13a1df146b.jpg
# Found 14 inliers for image : 09287a40e17ea137.jpg
# Found 13 inliers for image : ee8cb7b59aaf4b74.jpg
# Found 16 inliers for image : a6df1e2fd0c021ac.jpg
# Found 13 inliers for image : a938bf9313867954.jpg
# Found 15 inliers for image : f9bcd53d48259220.jpg
# Found 12 inliers for image : 607c2d3a9b400da8.jpg
# Found 6 inliers for image : 557f33defed30b43.jpg
# Found 13 inliers for image : ebe1054eede50aae.jpg
# Found 14 inliers for image : f3cb656a6cf99166.jpg
# Found 13 inliers for image : 08a85f7a4d697f09.jpg
# Found 16 inliers for image : a84176cdbd50c71c.jpg
# Found 13 inliers for image : f162ad3a2dd66f89.jpg
# Found 15 inliers for image : b42b7163616df967.jpg
# Found 15 inliers for image : c8774f456e53d8c0.jpg
# Found 12 inliers for image : 72d37013858d7b68.jpg
# Found 13 inliers for image : beb75e55ee1f2097.jpg
# Found 11 inliers for image : b0f55a0d1f485cb4.jpg
# Found 15 inliers for image : d47245ca010296db.jpg
# Found 16 inliers for image : 1c46eb080fb3466e.jpg
# Found 14 inliers for image : 4067a457cd9bb71d.jpg
# Found 14 inliers for image : afa2969b151ce538.jpg
# Found 14 inliers for image : f909989d186f6a42.jpg
# Found 14 inliers for image : 958d003e4e349b87.jpg
# Found 12 inliers for image : 6ca4f3e798b71029.jpg
# Found 14 inliers for image : 3629276fa5b376f2.jpg
# Found 11 inliers for image : 59f4912a1fff6abd.jpg
# Found 15 inliers for image : abcb1dcc649f6dfe.jpg
# Found 18 inliers for image : 4f420991b27bebb7.jpg
# Found 10 inliers for image : cdd563a2801777ae.jpg
# Found 15 inliers for image : a8618406a2db3958.jpg
# Found 17 inliers for image : acc1d2f042303981.jpg
# Found 13 inliers for image : ce4a4c658390d032.jpg
# Found 16 inliers for image : 8d599337ea3ab0ce.jpg
# Found 16 inliers for image : 4bed799123d1ad56.jpg
# Found 16 inliers for image : 2ad7bd1c05d0655c.jpg
# Found 13 inliers for image : 1e8e7db82e5d955a.jpg
# Found 18 inliers for image : 795aecdcd72a2ac0.jpg
# Found 14 inliers for image : 498e898c6d6662fe.jpg
# Found 14 inliers for image : 3a5a186965e60299.jpg
# Found 14 inliers for image : cb83d01bda550f93.jpg
# Found 14 inliers for image : 5eef56283fba4d2f.jpg
# Found 15 inliers for image : 70f5c0a2bbdfce6f.jpg
# Found 14 inliers for image : 019b40f8dd30e7b8.jpg
# Found 16 inliers for image : 9c3a4735e85781c1.jpg
# Found 14 inliers for image : a92fcdbe6a5e450e.jpg
# Found 11 inliers for image : 47fa19a557300bd8.jpg
# Found 14 inliers for image : c6b1a1b303cdb53a.jpg
# Found 18 inliers for image : 2a9e1f5ef1a57543.jpg
# Found 10 inliers for image : 746d033aacdeb8a4.jpg
# Found 12 inliers for image : d8a918fd26e4c710.jpg
# Found 15 inliers for image : 758ca3c723ce77d6.jpg
# Found 10 inliers for image : c5755c70ce833453.jpg
# Found 15 inliers for image : 8c1e819a7f63b0ec.jpg
# Found 14 inliers for image : 79363b9679a0a828.jpg
# Found 15 inliers for image : 72dda67b57a481ed.jpg
# Found 11 inliers for image : df9fcec52ac9c6fa.jpg
# Found 10 inliers for image : 1efd82154a2556c8.jpg
# Found 15 inliers for image : df8632c22b580d6d.jpg
# Found 14 inliers for image : 23edebcf8d2acb97.jpg
# Found 17 inliers for image : b0a824cbd08e019e.jpg
# Found 11 inliers for image : 8d1a7838e3328321.jpg
# Found 13 inliers for image : 0070b0960ae92c14.jpg
# Found 11 inliers for image : a4b6fe7b72005ac6.jpg
# Found 13 inliers for image : 01adea145c9c88c7.jpg
# Found 12 inliers for image : 4d6014220144c17f.jpg
# Found 6 inliers for image : 96d55734414382af.jpg
# Found 14 inliers for image : 317fd548bf0ce7ea.jpg
# Found 16 inliers for image : fab2be691667f47c.jpg
# Found 12 inliers for image : 9ef0c17f26803ead.jpg
# Found 14 inliers for image : 6b05227e25fdb494.jpg
# Found 13 inliers for image : d18e8002a1b905aa.jpg
# Found 14 inliers for image : a012ef3d8a344176.jpg
# Found 13 inliers for image : ad60afea0399f43b.jpg

# %%
reranked_df.to_csv("./csv_lookups/reranked_retrievals_delf_v1.csv")
reranked_df.head()
# Out:
#        queryImageID                 0                 1                 2  \
# 0  f60a52c609ab0208  6743b01ed9a80b21  795382a3476eef45  f7516eb6373880a8
# 1  4fa678d60ab4bc23  9adc544d34892d6a  a153c9c6daa1c533  9a720ea3a239c7e2
# 2  5be9d8002f8dc60e  4f420991b27bebb7  795aecdcd72a2ac0  2a9e1f5ef1a57543
#
#                   3                 4                 5                 6  \
# 0  5b317bd61482003e  5b66021e346ab3c8  0ac20102062fcfe4  2389c6f3ae0d098c
# 1  921f02216a181a18  9458354974361f83  094dd3087b8eb2b6  3dfe0a1b754c2b79
# 2  eebf7fc00415e13e  7989bf0178906d80  acc1d2f042303981  b0a824cbd08e019e
#
#                   7                 8  ...                90  \
# 0  06591603c89ba406  cb160c4a3ebcf864  ...  f87b9cbd29f65b13
# 1  bf62dece3bcddfef  201e24b5cea6c46d  ...  bc1256effd2d1a3e
# 2  d0abe024e8e92459  6e709c5b726a7527  ...  47fa19a557300bd8
#
#                  91                92                93                94  \
# 0  fc7af51823e9137a  d9467598a6f2c341  00f76a32545a61fa  3171bbb1efba8ded
# 1  f4cc1116e22ccd10  25ec89b5e07e16b8  ff8d7a1abf8b0c53  e19b111562e7ea47
# 2  df9fcec52ac9c6fa  8d1a7838e3328321  a4b6fe7b72005ac6  cdd563a2801777ae
#
#                  95                96                97                98  \
# 0  5a17c286f55000f8  9543cd918ee87e38  b22b1d598e405a32  4025b17b3449da20
# 1  1adfc00c2c6689e6  f904c847e26279b1  58462343843646b0  5f443f06cae15cd5
# 2  746d033aacdeb8a4  c5755c70ce833453  1efd82154a2556c8  557f33defed30b43
#
#                  99
# 0  c1a50fc8a5713159
# 1  07b7f7489addcf6e
# 2  96d55734414382af
#
# [3 rows x 101 columns]

# %%
def AP_at(retrieved, matches, k=5):
    GTP = len(set(matches)) # Ground-Truth True Positives
    if GTP==0:
        return 0
    TP_seen = 0
    P_sum = 0 # sum of precision
    for i, r in enumerate(retrieved):
        if r in matches:
            TP_seen += 1
            P_sum += (TP_seen) / (i+1)
    print(P_sum)
    return P_sum/GTP

def mAP_at(retrieved_arr, matches_arr, num_query=100):
    assert len(retrieved_arr)==len(matches_arr)
    # assert len(retrieved_arr)>=K
    cumulative_AP = 0
    for i in range(num_query):
        retrieved = retrieved_arr[i]
        matches = matches_arr[i]
        cumulative_AP += AP_at(retrieved, matches, i+1)

    print(cumulative_AP)
    return cumulative_AP / num_query

# %%
retrieved_solution = reranked_df.iloc[:, 1:] # cropping out only the retrieved-db-image IDs
retrieved_solution = retrieved_solution.values.tolist()

# %%
solution_df = pd.read_csv(Q_LOOKUP_CSV)
grountruth_solution = solution_df.iloc[:, 2:]
grountruth_solution = grountruth_solution.values.tolist()

# %%
print(len(retrieved_solution))
print(len(grountruth_solution[:3]))
print(len(retrieved_solution[0]))
print(len(grountruth_solution[:3][0]))
mAP_at(retrieved_solution, grountruth_solution[:3], 3)
# Out:
# 3
# 3
# 100
# 100
# 0
# 0
# 0
# 0.0
# 0.0

# %%
import ml_metrics as metrics
sol1 = metrics.mapk(grountruth_solution[0], retrieved_solution[0], 100)
sol2 = metrics.mapk(grountruth_solution[1], retrieved_solution[1], 100)
sol3 = metrics.mapk(grountruth_solution[2], retrieved_solution[2], 100)
print(sol1)
print(sol2)
print(sol3)

mAPk_cum = 0
TOP_K = 100
for q in range(len(retrieved_solution)):
    mAPk_cum += metrics.mapk(grountruth_solution[q], retrieved_solution[q], TOP_K)

mAPk_avg = mAPk_cum/len(retrieved_solution)
print(mAPk_cum)
print("mAP across first 3 queries : ", mAPk_avg)
# Out:
# 0.2653045704295704
# 0.12397819454850705
# 0.21415891573704068
# 0.6034416807151182
# mAP across first 3 queries :  0.2011472269050394
